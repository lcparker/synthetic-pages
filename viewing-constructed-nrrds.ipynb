# %%
# %load_ext autoreload
# %autoreload 1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %aimport nrrd_file

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from pathlib import Path

nrrds_dir = Path("/Users/lachlan/Code/nrrds2/")

# %%
nrrds_dir.ls()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 nrrds_dir.ls()
#
# AttributeError: 'PosixPath' object has no attribute 'ls'

# %%
# add ls method to pathlib.Path
def ls(self: Path):
    return sorted(list(self.iterdir()))

Path.ls = ls

# %%
nrrds_dir.ls()[:50]
# Out:
# [PosixPath('/Users/lachlan/Code/nrrds2/00128_02048_02048_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02048_02176_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02048_02304_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02048_02432_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02048_02560_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02048_02688_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02048_02816_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02048_02944_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02048_03072_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02048_03200_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02048_03328_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02048_03456_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02048_03584_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02048_03712_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02048_03840_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02048_03968_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02176_02048_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02176_02176_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02176_02304_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02176_02432_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02176_02560_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02176_02688_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02176_02816_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02176_02944_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02176_03072_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02176_03200_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02176_03328_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02176_03456_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02176_03584_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02176_03712_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02176_03840_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02176_03968_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02304_02048_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02304_02176_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02304_02304_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02304_02432_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02304_02560_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02304_02688_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02304_02816_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02304_02944_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02304_03072_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02304_03200_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02304_03328_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02304_03456_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02304_03584_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02304_03712_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02304_03840_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02304_03968_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02432_02048_volume.nrrd'),
#  PosixPath('/Users/lachlan/Code/nrrds2/00128_02432_02176_volume.nrrd')]

# %%
def load_four(dir: Path|str, z_lower: int, y_lower: int, x_lower: int):
    ul = Nrrd.from_file(Path(dir)/f'{z_lower:05d}_{y_lower:05d}_{x_lower:05d}_volume.nrrd')
    y_step, x_step = ul.volume.shape[1:]
    bl = Nrrd.from_file(Path(dir)/f'{z_lower:05d}_{y_lower:05d}_{x_lower+x_step:05d}_volume.nrrd')
    ur = Nrrd.from_file(Path(dir)/f'{z_lower:05d}_{y_lower+y_step:05d}_{x_lower:05d}_volume.nrrd')
    br = Nrrd.from_file(Path(dir)/f'{z_lower:05d}_{y_lower+y_step:05d}_{x_lower+x_step:05d}_volume.nrrd')
    return ul, ur, bl, br

x_lower = 2304
y_lower = 2304

nrrds_folder = Path("/Users/lachlan/Code/nrrds2/")
ul, ur, bl, br = load_four(nrrds_folder, 128, 2304, 2304)

# %%
def combine_four_slices(z_slice: int, ul, ur, bl, br):
    yd, xd = ul.volume.shape[1:]
    if not 0 <= z_slice <= ul.volume.shape[0] - 1:
        raise ValueError("argument z_slice was outside range (0, ul.volume.shape[1] - 1")

    img = np.zeros((2 * yd, 2 * xd))
    img[:xd, :yd] = ul.volume[z_slice].T
    img[:xd, yd:] = ur.volume[z_slice].T
    img[xd:, :yd] = bl.volume[z_slice].T
    img[xd:, yd:] = br.volume[z_slice].T
    return img

img = combine_four_slices(127, ul, ur, bl, br)
plt.imshow(img, cmap='gray')

# %%
def show_four_axial(z: int, y: int, x: int, nrrds_dir: Path|str):
    ul, ur, bl, br = load_four(Path(nrrds_dir), z, y, x)
    img = combine_four_slices(64, ul, ur, bl, br)
    plt.imshow(img, cmap='gray')

show_four_axial(128, 2304, 2304, nrrds_folder)

# %%
ul.metadata
# Out:
# OrderedDict([('type', 'uint16'),
#              ('dimension', 3),
#              ('space', 'left-posterior-superior'),
#              ('sizes', array([128, 128, 128])),
#              ('space directions',
#               array([[1., 0., 0.],
#                      [0., 1., 0.],
#                      [0., 0., 1.]])),
#              ('kinds', ['domain', 'domain', 'domain']),
#              ('endian', 'little'),
#              ('encoding', 'gzip'),
#              ('space origin', array([2304., 2304.,  128.]))])

# %% [markdown]
# ## Viewing the slice to figure out what i've done wrong

# %%
from PIL import Image

# %%
slice_255 = Image.open("/Users/lachlan/Code/full_scrolls/Scroll1/PHercParis4.volpkg/volumes/20230901234823/255.tif")
slice_255 = np.array(slice_255)

# %%
plt.imshow(slice_255, cmap='gray')

# %%
plt.imshow(slice_255[2304:2304+256, 2304:2304+256])
